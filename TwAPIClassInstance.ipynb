# %% [markdown]
# ### Instance of TwitterAPITools
# * Pengyu Xiao    Mar 2021

# %%
from TwitterAPITools.APIScraper import TimelineScraper, UserFolScraper

# %%
# username = "zhangziyi06"
# fdir = r"C:\Codes\AnonClassify\ScrapeData\Group2"
# btoken = bearer_token = "AAAAAAAAAAAAAAAAAAAAABclLgEAAAAA%2Fka5GHCEomJcAuZigc8mgmQ5cTg%3DdQs7LinkRug5oIXVLel9YyG9kGi5lnr3NeWb0zWPgeF34zt3Pr"
# ofile = r"C:\Codes\AnonClassify\ScrapeData\Group2\log.txt"

# %% [markdown]
# ### Timeline

# %%
fdir = r"C:/Codes/AnonClassify/ScrapeData/Group2"
btoken = "AAAAAAAAAAAAAAAAAAAAABclLgEAAAAA%2Fka5GHCEomJcAuZigc8mgmQ5cTg%3DdQs7LinkRug5oIXVLel9YyG9kGi5lnr3NeWb0zWPgeF34zt3Pr"
ofile = r"C:/Codes/AnonClassify/ScrapeData/Group2/log.txt"

# %%
tscraper = TimelineScraper(btoken)
# Out:
# 4

# %%
tscraper.workFromUserDir(fdir, ofile)
# Out:
# UID:1010626282906796033
# Start
# connecting
# {'meta': {'result_count': 0}}
# UID:1019942081807216640
# Start
# connecting
# {'errors': [{'parameter': 'id', 'resource_id': '1019942081807216640', 'value': '1019942081807216640', 'detail': 'User has been suspended: [1019942081807216640].', 'title': 'Forbidden', 'resource_type': 'user', 'type': 'https://api.twitter.com/2/problems/resource-not-found'}]}
# UID:1032138708978302976
# Start
# connecting
# ...
